# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import glob

# %matplotlib inline

# %% [markdown]
# ### Reading Accelerometer and Gyroscope data from csv files

# %%
path = "./single_task/Acc/" # use your path
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

accelerometer_data = pd.concat(li, axis=0, ignore_index=True)

# %%
path = "./single_task/Gyro/" # use your path
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

gyroscope_data = pd.concat(li, axis=0, ignore_index=True)

# %%
accelerometer_data.shape
# Out:
# (2698, 6)

# %%
gyroscope_data.shape
# Out:
# (2698, 6)

# %%
path = "./single_task/Acc/" # use your path
all_files = glob.glob(path + "Rajneesh_*.csv")

li = []
count = 0 
for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    df["time (-07:00)"] = pd.to_datetime(df["time (-07:00)"])
    x = int(df1["time (-07:00)"].head(1).dt.second)
    y = int(df1["time (-07:00)"].tail(1).dt.second)
    count += y - x 
    li.append(df)

print("Total second ", count)
print("No of activities ",len(li))
print("Average Time(seconds) ", count/len(li))
accelerometer_data = pd.concat(li, axis=0, ignore_index=True)
# Out:
# Total second  20
# No of activities  2
# Average Time(seconds)  10.0

# %%
accelerometer_data.iloc[:, [3,4,5]].plot(figsize=(15,8))

# %%
path = "./single_task/Acc/" # use your path
all_files = glob.glob(path + "Rajneesh_*.csv")

li = []
count = 0 
for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    df["time (-07:00)"] = pd.to_datetime(df["time (-07:00)"])
    df.iloc[:, [3,4,5]].plot(figsize=(10,5))
    
#accelerometer_data = pd.concat(li, axis=0, ignore_index=True)

# %%
path = "./single_task/Acc/" # use your path
all_files = glob.glob(path + "Sumit*.csv")

li = []
count = 0 
for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    df["time (-07:00)"] = pd.to_datetime(df["time (-07:00)"])
    x = int(df1["time (-07:00)"].head(1).dt.second)
    y = int(df1["time (-07:00)"].tail(1).dt.second)
    count += y -x 
    li.append(df)

print("Total second ", count)
print("No of activities ",len(li))
print("Average Time(seconds) ", count/len(li))
accelerometer_data = pd.concat(li, axis=0, ignore_index=True)
# Out:
# Total second  30
# No of activities  3
# Average Time(seconds)  10.0

# %%
accelerometer_data.iloc[:, [3,4,5]].plot(figsize=(20,10))

# %%
path = "./single_task/Acc/" # use your path
all_files = glob.glob(path + "Sumit*.csv")

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    df["time (-07:00)"] = pd.to_datetime(df["time (-07:00)"])
    df.iloc[:, [3,4,5]].plot(figsize=(10,5))

# %%
path = "./single_task/Gyro/" # use your path
all_files = glob.glob(path + "Rajneesh_*.csv")

li = []
count = 0 
for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    df["time (-07:00)"] = pd.to_datetime(df["time (-07:00)"])
    x = int(df1["time (-07:00)"].head(1).dt.second)
    y = int(df1["time (-07:00)"].tail(1).dt.second)
    count += y -x 
    li.append(df)

print("Total second ", count)
print("No of activities ",len(li))
print("Average Time(seconds) ", count/float(len(li)))
gyroscope_data = pd.concat(li, axis=0, ignore_index=True)
# Out:
# Total second  20
# No of activities  2
# Average Time(seconds)  10.0

# %%
gyroscope_data.iloc[:, [3,4,5]].plot(figsize=(20,10))

# %%
path = "./single_task/Gyro/" # use your path
all_files = glob.glob(path + "Rajneesh*.csv")

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    df["time (-07:00)"] = pd.to_datetime(df["time (-07:00)"])
    df.iloc[:, [3,4,5]].plot(figsize=(10,5))

# %%
path = "./single_task/Gyro/" # use your path
all_files = glob.glob(path + "Sumit*.csv")

li = []
count = 0 
for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    df["time (-07:00)"] = pd.to_datetime(df["time (-07:00)"])
    x = int(df1["time (-07:00)"].head(1).dt.second)
    y = int(df1["time (-07:00)"].tail(1).dt.second)
    count += y -x 
    li.append(df)

print("Total second ", count)
print("No of activities ",len(li))
print("Average Time(seconds) ", count/float(len(li)))
gyroscope_data = pd.concat(li, axis=0, ignore_index=True)
# Out:
# Total second  30
# No of activities  3
# Average Time(seconds)  10.0

# %%
gyroscope_data.iloc[:, [3,4,5]].plot(figsize=(15,10))

# %%
path = "./single_task/Gyro/" # use your path
all_files = glob.glob(path + "Sumit*.csv")


for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    df["time (-07:00)"] = pd.to_datetime(df["time (-07:00)"])
    df.iloc[:, [3,4,5]].plot(figsize=(10,5))
